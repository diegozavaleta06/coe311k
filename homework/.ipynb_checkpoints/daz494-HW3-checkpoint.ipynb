# %%
def factorial (x):
    upval = x
    for z in range(1,x):
        upval = upval * (x-z)
    print(upval)
    return(upval)




def sin_number(terms):
    
    for k in range(0,10,0.1):
        sum = k
        flipper = 2
        expy = 3
        
        for i in range(terms):
            term = (k**expy) / factorial(expy)
            if flipper%2 == 0:
                 sum = sum -  term
            if flipper%2 == 1:
                sum = sum + term   
            expy += 2
            flipper += 1
            real_sin = numpy.sin(k)
            abs_error = real_sin - term

# %%
# Out:
# 5040
# 5040
