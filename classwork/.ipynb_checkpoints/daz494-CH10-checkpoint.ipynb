# %%
import numpy as np
''' 
THIS IS PART A OF THE CHALLENGE
'''
X = np.arange(0, 1.01, 0.01)
random_shift = np.random.uniform(-1, 1, len(X))
Y = (12*X+2) + random_shift
A = np.vstack([X, np.ones(len(X))]).T

m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
import matplotlib.pyplot as plt
y_pred_linear = m * X + c
plt.scatter(X, Y)
plt.plot(X,m*X + c, 'r', label = f'Least Squares method')


#MSE and R-Values for least squares method. 
mse1 = np.mean((Y - y_pred_linear)**2)
print(f'Mean Squared Error for least squares: {mse1:.4f}')
# R-squared value
ss_total1 = np.sum((Y - np.mean(Y))**2)
ss_res1 = np.sum((Y - y_pred_linear)**2)
r_squared1 = 1 - (ss_res1 / ss_total1)
print(f'R-squared for least squares: {r_squared1:.4f}\n')




degree =  3 # Degree of the polynomial
coefficients = np.polyfit(X, Y, degree)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(X)
plt.plot(X, y_pred, color='green', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error for polynomial: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared for polynomial: {r_squared:.4f}')
plt.show()

if r_squared1 > r_squared:
    print("The least squares approach was better")
else:
    print("The polynomial fit was better")
# Out:
# Slope: 11.999535281886928, Intercept: 2.056078256859883
# Mean Squared Error for least squares: 0.3072
# R-squared for least squares: 0.9755
#
# Mean Squared Error for polynomial: 0.2999
# R-squared for polynomial: 0.9761
# The polynomial fit was better

# %%
def poly(degree_num, X, Y):
    coefficients = np.polyfit(X, Y, degree_num)
    polynomial = np.poly1d(coefficients)
    y_pred = polynomial(X)
    return y_pred
def least_squares(X,Y):
    random_shift = np.random.uniform(-1, 1, len(X))
    A = np.vstack([X, np.ones(len(X))]).T
    m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
    y_pred_linear = m * X + c
    return m, c, y_pred_linear

# %%
X = np.arange(0, 1.01, 0.01)
random_shift = np.random.uniform(-1, 1, len(X))
Y = (12*X+2) + random_shift

m,c,y_pred_linear = least_squares(X,Y)

#MSE and R-Values for least squares method. 
mse1 = np.mean((Y - y_pred_linear)**2)
# R-squared value
ss_total1 = np.sum((Y - np.mean(Y))**2)
ss_res1 = np.sum((Y - y_pred_linear)**2)
r_squared1 = 1 - (ss_res1 / ss_total1)


for d in range(1,21):
    plt.figure()
    plt.scatter(X, Y)
    plt.plot(X,m*X + c, 'r', label = f'Least Squares method')

    print(f'Mean Squared Error for least squares: {mse1:.4f}')
    print(f'R-squared for least squares: {r_squared1:.4f}')

    y_pred = poly(d,X,Y)
    plt.plot(X, y_pred, color='green', label=f'Polynomial fit of degree {d}')
    # Mean Squared Error (MSE)
    mse = np.mean((Y - y_pred)**2)
    print(f'Mean Squared Error for polynomial degree {d}: {mse:.4f}')
    # R-squared value
    ss_total = np.sum((Y - np.mean(Y))**2)
    ss_res = np.sum((Y - y_pred)**2)
    r_squared = 1 - (ss_res / ss_total)
    print(f'R-squared for polynomial degree {d}: {r_squared:.4f}')

    if r_squared1 > r_squared:
        print("The least squares approach was better")
    else:
        print("The polynomial fit was better\n")
    plt.legend() 
        
plt.show()
# Out:
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 1: 0.3204
# R-squared for polynomial degree 1: 0.9760
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 2: 0.3197
# R-squared for polynomial degree 2: 0.9760
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 3: 0.3194
# R-squared for polynomial degree 3: 0.9760
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 4: 0.3187
# R-squared for polynomial degree 4: 0.9761
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 5: 0.3135
# R-squared for polynomial degree 5: 0.9765
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 6: 0.3130
# R-squared for polynomial degree 6: 0.9765
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 7: 0.3130
# R-squared for polynomial degree 7: 0.9765
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 8: 0.3033
# R-squared for polynomial degree 8: 0.9773
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 9: 0.3021
# R-squared for polynomial degree 9: 0.9773
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 10: 0.2894
# R-squared for polynomial degree 10: 0.9783
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 11: 0.2893
# R-squared for polynomial degree 11: 0.9783
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 12: 0.2893
# R-squared for polynomial degree 12: 0.9783
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 13: 0.2864
# R-squared for polynomial degree 13: 0.9785
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 14: 0.2859
# R-squared for polynomial degree 14: 0.9786
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 15: 0.2834
# R-squared for polynomial degree 15: 0.9787
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 16: 0.2812
# R-squared for polynomial degree 16: 0.9789
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 17: 0.2794
# R-squared for polynomial degree 17: 0.9790
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 18: 0.2769
# R-squared for polynomial degree 18: 0.9792
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 19: 0.2776
# R-squared for polynomial degree 19: 0.9792
# The polynomial fit was better
#
# Mean Squared Error for least squares: 0.3204
# R-squared for least squares: 0.9760
# Mean Squared Error for polynomial degree 20: 0.2750
# R-squared for polynomial degree 20: 0.9794
# The polynomial fit was better
# <ipython-input-3-76c12e69f2a7>:23: RankWarning: Polyfit may be poorly conditioned
#   y_pred = poly(d,X,Y)
# <ipython-input-3-76c12e69f2a7>:23: RankWarning: Polyfit may be poorly conditioned
#   y_pred = poly(d,X,Y)

# %%
import numpy as np
''' 
THIS IS PART C OF THE CHALLENGE
'''
X = np.arange(0, 1.01, 0.01)
random_shift = np.random.uniform(-1, 1, len(X))
Y = (12*X+2) + random_shift
A = np.vstack([X, np.ones(len(X))]).T

m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
import matplotlib.pyplot as plt
y_pred_linear = m * X + c
plt.scatter(X, Y)
plt.plot(X,m*X + c, 'r', label = f'Least Squares method')


#MSE and R-Values for least squares method. 
mse1 = np.mean((Y - y_pred_linear)**2)
print(f'Mean Squared Error for least squares: {mse1:.4f}')
# R-squared value
ss_total1 = np.sum((Y - np.mean(Y))**2)
ss_res1 = np.sum((Y - y_pred_linear)**2)
r_squared1 = 1 - (ss_res1 / ss_total1)
print(f'R-squared for least squares: {r_squared1:.4f}\n')


degree = 3
V = np.vander(X, N=degree+1, increasing=True)
VT_V = np.dot(V.T, V)
VT_y = np.dot(V.T, Y)
coefficients = np.linalg.solve(VT_V, VT_y)
polynomial = np.poly1d(coefficients[::-1])
y_pred = polynomial(X)
plt.plot(X, y_pred, color='green', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error for polynomial: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared for polynomial: {r_squared:.4f}')
plt.show()

if r_squared1 > r_squared:
    print("The least squares approach was better")
else:
    print("The polynomial fit was better")
# Out:
# Slope: 12.107580708242006, Intercept: 1.9112443775941914
# Mean Squared Error for least squares: 0.3196
# R-squared for least squares: 0.9750
#
# Mean Squared Error for polynomial: 0.3157
# R-squared for polynomial: 0.9753
# The polynomial fit was better
