# %%
import numpy as np
import matplotlib.pyplot as plt

listy2 = [0.1,1.0,10.0]
for kval in listy2:
    plt.figure(figsize=(10, 5))

    listy = [0.01,0.02,0.03,0.05,0.1,0.2,0.3,0.5]
    for hval in listy:
        # Define the parameters
        k = kval        # Constant in the equation (e.g., spring constant)
        h = hval      # Step size
        x_start = 0    # Start of the interval
        x_end = 10     # End of the interval
        y_0 = 1.0      # Initial condition for y
        v_0 = 0.0      # Initial condition for dy/dx

        # Create arrays to store x, y, and v values

        x_values = np.arange(x_start, x_end + h, h)
        y_values = np.zeros(len(x_values))
        v_values = np.zeros(len(x_values))

        # Set initial conditions

        y_values[0] = y_0
        v_values[0] = v_0

        # Euler's Method loop

        for i in range(1, len(x_values)):
            # Current values
            x_n = x_values[i - 1]
            y_n = y_values[i - 1]
            v_n = v_values[i - 1]    

            # Update equations
            y_values[i] = y_n + h * v_n
            v_values[i] = v_n + h * (-k * y_n)



        # Plot the results

        plt.plot(x_values, y_values, label=f'h={h} (Pos)')
        plt.plot(x_values, v_values, label='Velocity v(x)', linestyle='--')


    plt.xlabel('x')
    plt.ylabel('y and v')
    plt.title('Solution of d²y/dx² = -ky using Euler\'s Method')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# It starts to become unstable at areound h = 0.1, there you can see it starts varying by a noticeable amount.

# %%
# As the k value goes from smaller to larger, it starts to get worse for the larger h values. The smallest k value works with all the h values.
