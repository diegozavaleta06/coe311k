# %%
import time
def naive_matrix_multiplication(A, B):
    n = len(A)
    C = [[0] * n for _ in range(n)]
    for i in range(n):
        for j in range(n):
            for k in range(n):
                C[i][j] += A[i][k] * B[k][j]
    return C

import numpy as np

n = 3  
matrix_pairs = []

for i in range(8):
    A = np.random.rand(n, n)
    B = np.random.rand(n, n)
    
    matrix_pairs.append((A, B))
    
    print(f"Pair {i+1} generated: {n}x{n}")
    n *= 2  

counter = 1
naive_list = []
for i in matrix_pairs:
    A, B = i
    start_time = time.time()
    result = naive_matrix_multiplication(A,B)
    end_time = time.time()
    duration = end_time - start_time
    print(f"The naive method took {duration} seconds for iteration {counter}.")
    naive_list.append(duration)
    counter += 1
print("\n")
counter = 1
np_list = []
for i in matrix_pairs:
    A, B = i
    start_time = time.time()
    result = np.dot(A,B)
    end_time = time.time()
    duration = end_time - start_time
    print(f"The numpy method took {duration} seconds for iteration {counter}.")
    np_list.append(duration)
    counter += 1    
    
import matplotlib.pyplot as plt

xlength = [1,2,3,4,5,6,7,8]
plt.plot(xlength,naive_list, label = 'naive')
plt.plot(xlength,np_list, label = 'np')
plt.title('Matrix Multiplication Runtime')
plt.xlabel('Iteration Number')
plt.ylabel('Time')
plt.legend()
plt.show()
# Out:
# Pair 1 generated: 3x3
# Pair 2 generated: 6x6
# Pair 3 generated: 12x12
# Pair 4 generated: 24x24
# Pair 5 generated: 48x48
# Pair 6 generated: 96x96
# Pair 7 generated: 192x192
# Pair 8 generated: 384x384
# The naive method took 9.560585021972656e-05 seconds for iteration 1.
# The naive method took 0.0003986358642578125 seconds for iteration 2.
# The naive method took 0.00215911865234375 seconds for iteration 3.
# The naive method took 0.014675140380859375 seconds for iteration 4.
# The naive method took 0.11995220184326172 seconds for iteration 5.
# The naive method took 0.9795777797698975 seconds for iteration 6.
# The naive method took 7.009428977966309 seconds for iteration 7.
# The naive method took 58.73761701583862 seconds for iteration 8.
#
#
# The numpy method took 0.010567188262939453 seconds for iteration 1.
# The numpy method took 0.00027370452880859375 seconds for iteration 2.
# The numpy method took 2.5272369384765625e-05 seconds for iteration 3.
# ...
